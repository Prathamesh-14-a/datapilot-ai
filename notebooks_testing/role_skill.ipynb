# %%
import pandas as pd

# %%
df = pd.read_csv(r'd:\Startup\Project\ai-career-coach\data\job_fit_dataset.csv')

print(df.shape)
print()
print(df.tail())
print()
print(df["target_role"].value_counts())
# Out:
# (3500, 2)
#
#                                                  skills         target_role
# 3495  etl,teamwork,sql,data warehouse,python,hadoop,...       Data Engineer
# 3496  sql,spark,etl,airflow,aws,python,database desi...       Data Engineer
# 3497  azure,data warehouse,aws,airflow,hadoop,python...       Data Engineer
# 3498  scikit-learn,machine learning,numpy,feature en...      Data Scientist
# 3499  analytics engineering,bigquery,snowflake,data ...  Analytics Engineer
#
# target_role
# Machine Learning Engineer    500
# Business Analyst             500
# Data Analyst                 500
# Data Engineer                500
# BI Analyst                   500
# Analytics Engineer           500
# Data Scientist               500
# Name: count, dtype: int64

# %%
df.sample(10)
# Out:
#                                                  skills  \
# 572   statistics,deep learning,model deployment,time...
# 3329  statistics,data visualization,tableau,reportin...
# 3197  communication,deep learning,python,statistics,...
# 1624  sql,communication,statistics,tableau,power bi,...
# 3198  data modeling,sql,python,airflow,etl,snowflake...
# 2422  data warehouse,teamwork,database design,python...
# 736   kubernetes,deep learning,python,machine learni...
# 3449  teamwork,snowflake,data warehouse,bigquery,tim...
# 2805  docker,mlops,python,model deployment,machine l...
# 2680  data visualization,requirements gathering,stak...
#
#                     target_role
# 572              Data Scientist
# 3329               Data Analyst
# 3197             Data Scientist
# 1624               Data Analyst
# 3198         Analytics Engineer
# 2422              Data Engineer
# 736   Machine Learning Engineer
# 3449         Analytics Engineer
# 2805  Machine Learning Engineer
# ...
